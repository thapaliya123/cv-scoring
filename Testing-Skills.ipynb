# %%
import re
import string as st
import warnings
warnings.filterwarnings('ignore')

import spacy
import nltk
from spacy.matcher import PhraseMatcher

from skillNer.skill_extractor_class import SkillExtractor
from skillNer.general_params import SKILL_DB

nlp = spacy.load("en_core_web_sm")

from nltk.stem.snowball import SnowballStemmer
from nltk import PorterStemmer, WordNetLemmatizer

from nltk.corpus import stopwords

# %%
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %% [markdown]
# ## Text cleaning and processing steps-
#
# - Remove punctuations
# - Convert text to tokens
# - Remove tokens of length less than or equal to 3
# - Remove stopwords using NLTK corpus stopwords list to match
# - Apply stemming
# - Apply lemmatization
# - Convert words to feature vectors

# %%
# extract skills from job_description
jd = """ Must have at least a bachelor's degree in Computer Science or similar. 
Min. 2 years of relevant work experience. Proficient in Basic Machine Learning concepts: algorithms, evaluation procedures, etc, and 
dealing with Common failure modes. Experienced in at least one area of application (E.g. CV, NLP, etc). 
Has a sound knowledge of mathematical concepts like Linear Algebra, Probability and Statistics, Calculus. 
Proficient in framework & libraries such as Numpy, Pandas, Matplotlib, Scikit-learn and a good grasp of at least one of Tensorflow or Pytorch.
Familiar with Flask, FastAPI or Django, and some domain-specific tools (e.g: opencv, spacy, etc). 
Good Grasp on programming language and concepts such as Python + OOP + SOLID, Data Structures and Algorithms, RESTful APIs, 
and familiar with Architecture Design. Good Grasp of software tools and platforms such as git, conda, pip, jupyter, Docker, 
and at least one cloud platform like AWS/GCP. Good grasp of a database such as SQL/NoSQL. Has a good grasp of 
agile processes like Sprint and Kanban. Good Team Management, Communication, and Problem-Solving Skills
"""

# %%
def remove_punct(text):
     # replace multiple white spaces with single white space
    return ("".join([ch for ch in text if ch not in st.punctuation]))
    return text
print(remove_punct(jd))
# Out:
#  Must have at least a bachelors degree in Computer Science or similar
# Min 2 years of relevant work experience Proficient in Basic Machine Learning concepts algorithms evaluation procedures etc and
# dealing with Common failure modes Experienced in at least one area of application Eg CV NLP etc
# Has a sound knowledge of mathematical concepts like Linear Algebra Probability and Statistics Calculus
# Proficient in framework  libraries such as Numpy Pandas Matplotlib Scikitlearn and a good grasp of at least one of Tensorflow or Pytorch
# Familiar with Flask FastAPI or Django and some domainspecific tools eg opencv spacy etc
# Good Grasp on programming language and concepts such as Python  OOP  SOLID Data Structures and Algorithms RESTful APIs
# and familiar with Architecture Design Good Grasp of software tools and platforms such as git conda pip jupyter Docker
# and at least one cloud platform like AWSGCP Good grasp of a database such as SQLNoSQL Has a good grasp of
# agile processes like Sprint and Kanban Good Team Management Communication and ProblemSolving Skills

# %%
def remove_punct(text):
     # replace multiple white spaces with single white space
    text = re.sub("\n|\\\\n|●|•|○|,|\/|-|–|\(|\)||\\\\", " ", text)
    text = re.sub(" +", " ", text)
    text = re.sub(r'[^\w\s]', '', text)
#     return ("".join([ch for ch in text if ch not in st.punctuation]))
    return text
print(remove_punct(jd))
# Out:
#  Must have at least a bachelors degree in Computer Science or similar Min 2 years of relevant work experience Proficient in Basic Machine Learning concepts algorithms evaluation procedures etc and dealing with Common failure modes Experienced in at least one area of application Eg CV NLP etc  Has a sound knowledge of mathematical concepts like Linear Algebra Probability and Statistics Calculus Proficient in framework  libraries such as Numpy Pandas Matplotlib Scikit learn and a good grasp of at least one of Tensorflow or Pytorch Familiar with Flask FastAPI or Django and some domain specific tools eg opencv spacy etc  Good Grasp on programming language and concepts such as Python  OOP  SOLID Data Structures and Algorithms RESTful APIs and familiar with Architecture Design Good Grasp of software tools and platforms such as git conda pip jupyter Docker and at least one cloud platform like AWS GCP Good grasp of a database such as SQL NoSQL Has a good grasp of agile processes like Sprint and Kanban Good Team Management Communication and Problem Solving Skills

# %%
# Remove all punctuations from the text

def remove_punct(text):
    return ("".join([ch for ch in text if ch not in st.punctuation]))

def tokenize(text):
    text = re.split('\s+' ,text)
    return [x.lower() for x in text]

# Remove tokens of length less than 3
def remove_small_words(text):
    return [x for x in text if len(x) > 3 ]

def remove_stopwords(text):
    return [word for word in text if word not in nltk.corpus.stopwords.words('english')]

# Apply stemming to get root words 
def stemming(text):
    sbs = SnowballStemmer(language='english')
    return [sbs.stem(word) for word in text]

# Apply lemmatization on tokens
def lemmatize(text):
    word_net = WordNetLemmatizer()
    return [word_net.lemmatize(word) for word in text]

# Create sentences to get clean text as input for vectors
def return_sentences(tokens):
    return " ".join([word for word in tokens])

# %%
def preprocessing():
    punct_cleaner = remove_punct(jd)
    token_word = tokenize(punct_cleaner)
    remove_word = remove_small_words(token_word)
    stopwords_cleaner = remove_stopwords(remove_word)
#     stemmed_word = stemming(stopwords_cleaner)
    lemma_word = lemmatize(stopwords_cleaner)
    clean_sent = return_sentences(lemma_word)
    return clean_sent

# %%
clean_jd = preprocessing()

# %%
clean_jd
# Out:
# 'must least bachelor degree computer science similar year relevant work experience proficient basic machine learning concept algorithm evaluation procedure dealing common failure mode experienced least area application sound knowledge mathematical concept like linear algebra probability statistic calculus proficient framework library numpy panda matplotlib scikitlearn good grasp least tensorflow pytorch familiar flask fastapi django domainspecific tool opencv spacy good grasp programming language concept python solid data structure algorithm restful apis familiar architecture design good grasp software tool platform conda jupyter docker least cloud platform like awsgcp good grasp database sqlnosql good grasp agile process like sprint kanban good team management communication problemsolving skill'

# %%
annotations = skill_extractor.annotate(clean_jd)

# %%
# inspect annotations
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspmust least bachelor degree&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS1226Y6DNDT05G7FJ4J_509()'onmouseenter='mouseEnterHandler_KS1226Y6DNDT05G7FJ4J_509()'>
#             computer science
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS1226Y6DNDT05G7FJ4J_509'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Computer Science
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             full_matches
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS1226Y6DNDT05G7FJ4J_509() {
#             document.getElementById("KS1226Y6DNDT05G7FJ4J_509").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS1226Y6DNDT05G7FJ4J_509() {
#             document.getElementById("KS1226Y6DNDT05G7FJ4J_509").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspsimilar year relevant work experience proficient basic&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_ES2933FAEF72CE4E2840_296()'onmouseenter='mouseEnterHandler_ES2933FAEF72CE4E2840_296()'>
#             machine learning
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='ES2933FAEF72CE4E2840_296'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Machine Learning Methods
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             0.6333333333333333
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_ES2933FAEF72CE4E2840_296() {
#             document.getElementById("ES2933FAEF72CE4E2840_296").style.display = "";
#         }
#
#         function mouseLeaveHandler_ES2933FAEF72CE4E2840_296() {
#             document.getElementById("ES2933FAEF72CE4E2840_296").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_ES2933FAEF72CE4E2840_803()'onmouseenter='mouseEnterHandler_ES2933FAEF72CE4E2840_803()'>
#             machine learning
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='ES2933FAEF72CE4E2840_803'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Machine Learning Methods
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             0.6333333333333333
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_ES2933FAEF72CE4E2840_803() {
#             document.getElementById("ES2933FAEF72CE4E2840_803").style.display = "";
#         }
#
#         function mouseLeaveHandler_ES2933FAEF72CE4E2840_803() {
#             document.getElementById("ES2933FAEF72CE4E2840_803").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbsp&nbsp &nbspconcept algorithm evaluation procedure dealing common failure mode experienced least area application sound knowledge mathematical concept like&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS125VF76P4FXDVFFBPJ_682()'onmouseenter='mouseEnterHandler_KS125VF76P4FXDVFFBPJ_682()'>
#             linear algebra
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS125VF76P4FXDVFFBPJ_682'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Linear Algebra
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             full_matches
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS125VF76P4FXDVFFBPJ_682() {
#             document.getElementById("KS125VF76P4FXDVFFBPJ_682").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS125VF76P4FXDVFFBPJ_682() {
#             document.getElementById("KS125VF76P4FXDVFFBPJ_682").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS440Y76XJ99KMMZBVXK_687()'onmouseenter='mouseEnterHandler_KS440Y76XJ99KMMZBVXK_687()'>
#             probability statistic
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS440Y76XJ99KMMZBVXK_687'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>

# %%
annotations
# Out:
# {'text': 'must have at least a bachelor s degree in computer science or similar min 2 years of relevant work experience proficient in basic machine learning concepts algorithms evaluation procedures etc and dealing with common failure modes experienced in at least one area of application e g cv nlp etc has a sound knowledge of mathematical concepts like linear algebra probability and statistics calculus proficient in framework & libraries such as numpy pandas matplotlib scikit learn and a good grasp of at least one of tensorflow or pytorch familiar with flask fastapi or django and some domain specific tools e g opencv spacy etc good grasp on programming language and concepts such as python + oop + solid data structures and algorithms restful apis and familiar with architecture design good grasp of software tools and platforms such as git conda pip jupyter docker and at least one cloud platform like aws gcp good grasp of a database such as sql nosql has a good grasp of agile processes like sprint and kanban good team management communication and problem solving skills',
#  'results': {'full_matches': [{'skill_id': 'KS1226Y6DNDT05G7FJ4J',
#     'doc_node_value': 'computer science',
#     'score': 1,
#     'doc_node_id': [9, 10]},
#    {'skill_id': 'KS125VF76P4FXDVFFBPJ',
#     'doc_node_value': 'linear algebra',
#     'score': 1,
#     'doc_node_id': [57, 58]},
#    {'skill_id': 'KS440Y76XJ99KMMZBVXK',
#     'doc_node_value': 'probability and statistic',
#     'score': 1,
#     'doc_node_id': [59, 60, 61]},
#    {'skill_id': 'KSJ2QBJ158RE1QN9D3AZ',
#     'doc_node_value': 'scikit learn',
#     'score': 1,
#     'doc_node_id': [73, 74]},
#    {'skill_id': 'KS122Q26BWQ1PK3Y74C0',
#     'doc_node_value': 'data structure',
#     'score': 1,
#     'doc_node_id': [117, 118]},
#    {'skill_id': 'KS441846K903WT1RYDKJ',
#     'doc_node_value': 'team management',
#     'score': 1,
#     'doc_node_id': [172, 173]},
#    {'skill_id': 'KS1275Z6908VHW76FRXH',
#     'score': 1,
#     'doc_node_value': 'OOP',
#     'doc_node_id': [114]},
#    {'skill_id': 'ESC7869CF7378283E0AA',
#     'score': 1,
#     'doc_node_value': 'GCP',
#     'doc_node_id': [150]}],
#   'ngram_scored': [{'skill_id': 'ES2933FAEF72CE4E2840',
#     'doc_node_id': [23, 24],
#     'doc_node_value': 'machine learning',
#     'type': 'oneToken',
#     'score': 0.6333333333333333,
#     'len': 2},
#    {'skill_id': 'ES2933FAEF72CE4E2840',
#     'doc_node_id': [23, 24],
#     'doc_node_value': 'machine learning',
#     'type': 'oneToken',
#     'score': 0.6333333333333333,
#     'len': 2},
#    {'skill_id': 'KS120D96FHL88PZDKZKH',
#     'doc_node_id': [26],
#     'doc_node_value': 'algorithms',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS123MP6KPNJF3GFZ5TS',
#     'doc_node_id': [44],
#     'doc_node_value': 'e',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS121BN5YN02RH41JHC7',
#     'doc_node_id': [62],
#     'doc_node_value': 'calculus',
#     'type': 'lowSurf',
#     'score': 1.0,
#     'len': 1},
#    {'skill_id': 'KS1274P66LZKSR1F2YCT',
#     'doc_node_id': [70],
#     'doc_node_value': 'numpy',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KSGWPO6DSN70GRY20JFT',
#     'doc_node_id': [71],
#     'doc_node_value': 'pandas',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS126796RG0M9JRLKDQY',
#     'doc_node_id': [72],
#     'doc_node_value': 'matplotlib',
#     'type': 'lowSurf',
#     'score': 1.0,
#     'len': 1},
#    {'skill_id': 'KS2GHRCYA6TRT29F1HOO',
#     'doc_node_id': [84],
#     'doc_node_value': 'tensorflow',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KSWXHT30GQY9B4QSXC5O',
#     'doc_node_id': [86],
#     'doc_node_value': 'pytorch',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'ES46B2FBE34B5D3E45D5',
#     'doc_node_id': [89],
#     'doc_node_value': 'flask',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS1232D6PH6SBVWWPQWC',
#     'doc_node_id': [92],
#     'doc_node_value': 'django',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'ESA9FBE7BF2274298757',
#     'doc_node_id': [95, 96],
#     'doc_node_value': 'domain specific',
#     'type': 'oneToken',
#     'score': 0.6333333333333333,
#     'len': 2},
#    {'skill_id': 'KS123P673QH23M3J84KR',
#     'doc_node_id': [97, 98],
#     'doc_node_value': 'tools e',
#     'type': 'lowSurf',
#     'score': 2,
#     'len': 2},
#    {'skill_id': 'KS12791657JTS84RWLVQ',
#     'doc_node_id': [100],
#     'doc_node_value': 'opencv',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'ESD67838331142BE19DF',
#     'doc_node_id': [101],
#     'doc_node_value': 'spacy',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS123CJ7656KLDB8MNRX',
#     'doc_node_id': [106, 107],
#     'doc_node_value': 'programming language',
#     'type': 'oneToken',
#     'score': 0.5666666666666668,
#     'len': 2},
#    {'skill_id': 'KS125LS6N7WP4S6SFTCK',
#     'doc_node_id': [112],
#     'doc_node_value': 'python',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS120D96FHL88PZDKZKH',
#     'doc_node_id': [120],
#     'doc_node_value': 'algorithms',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS4401V5WX78L6JX0NW7',
#     'doc_node_id': [121, 122],
#     'doc_node_value': 'restful apis',
#     'type': 'lowSurf',
#     'score': 2,
#     'len': 2},
#    {'skill_id': 'KS120MG6W03JCFGKFHHC',
#     'doc_node_id': [126, 127],
#     'doc_node_value': 'architecture design',
#     'type': 'lowSurf',
#     'score': 2,
#     'len': 2},
#    {'skill_id': 'KSIWWZAII4AP33SDVZ2H',
#     'doc_node_id': [137],
#     'doc_node_value': 'git',
#     'type': 'lowSurf',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KSFDBQT68SA9R0I0SAVH',
#     'doc_node_id': [140],
#     'doc_node_value': 'jupyter',
#     'type': 'lowSurf',
#     'score': 1.0,
#     'len': 1},
#    {'skill_id': 'KSY4WFI1S164RQUBSPCC',
#     'doc_node_id': [141],
#     'doc_node_value': 'docker',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS4426R6RWMFJJ8HC9RN',
#     'doc_node_id': [146, 147],
#     'doc_node_value': 'cloud platform',
#     'type': 'oneToken',
#     'score': 0.5666666666666668,
#     'len': 2},
#    {'skill_id': 'KS440W865GC4VRBW6LJP',
#     'doc_node_id': [158],
#     'doc_node_value': 'sql',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS1272Y6RFNZKNGWDWMB',
#     'doc_node_id': [159],
#     'doc_node_value': 'nosql',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS120BB6TZJLWQ8T3QK9',
#     'doc_node_id': [165, 166],
#     'doc_node_value': 'agile processes',
#     'type': 'oneToken',
#     'score': 0.6,
#     'len': 2},
#    {'skill_id': 'KS125F678LV2KB3Z5XW0',
#     'doc_node_id': [176, 177],
#     'doc_node_value': 'problem solving',
#     'type': 'lowSurf',
#     'score': 2,
#     'len': 2}]}}

# %%
def extract_hard_soft_skills(job_description):
    ''' 
       Extract hard skills, soft skills and certification from given job description 
       using pre-trained model SkillNER
    '''
    annotations = skill_extractor.annotate(job_description)
    list_words = annotations["text"].split(" ")
    hard_soft_skills = {'Hard Skill' : [],
                   'Soft Skill' : [],
                   'Certification': []}
    for type_matching, arr_skills in annotations["results"].items():
        for skill in arr_skills:
            # index word start and end
            start = skill["doc_node_id"][0]
            end = skill["doc_node_id"][-1]

             # meta data
            skill_id = skill["skill_id"]
#             skill_name = SKILL_DB[skill["skill_id"]]["skill_name"]
            skill_name = skill["doc_node_value"]
            skill_type = SKILL_DB[skill["skill_id"]]["skill_type"]
            hard_soft_skills[skill_type].append(skill_name)
            
    # extract unique hard and soft skills
    hard_soft_skills['Hard Skill'], hard_soft_skills['Soft Skill'] = list(set(hard_soft_skills['Hard Skill'])), list(set(hard_soft_skills['Soft Skill']))
    return hard_soft_skills

# %%
extract_hard_soft_skills(clean_jd)
# Out:
# {'Hard Skill': ['python',
#   'tool platform',
#   'computer science',
#   'jupyter',
#   'calculus',
#   'agile process',
#   'programming language',
#   'restful apis',
#   'linear algebra',
#   'opencv',
#   'data structure',
#   'library',
#   'tool',
#   'machine learning',
#   'probability statistic',
#   'docker',
#   'matplotlib',
#   'flask',
#   'django',
#   'numpy',
#   'architecture design',
#   'tensorflow',
#   'pytorch',
#   'cloud platform',
#   'spacy'],
#  'Soft Skill': ['team management'],
#  'Certification': []}
